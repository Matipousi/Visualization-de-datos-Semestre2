# %% [markdown]
# Encuesta realizada durante el año 2024 a participantes de actividades de Educación Permanente en la Universidad de la República durante el año 2023.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import re

# %%
# Cargar el dataset
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks')

df = pd.read_csv('encuesta-de-participantes_2024_portal_de_datos.csv', encoding='latin1')

# Ver primeras filas
df.head()
# Out:
#    Id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#   1. Para empezar ¿Cuántos cursos de educación permanente realizó el año pasado 2023?  \
# 0                                         Dos cursos
# 1                                         Dos cursos
# 2                                         Dos cursos
# 3  Ninguno (Terminar encuesta y pasar a la pregun...
# 4                                         Dos cursos
#
#   2. ¿Desde qué centro/facultad realizó el/los cursos? (puede marcar todas las que correspondan en caso de haber realizado dos cursos o más en diferentes centros)  \
# 0                                                FIC
# 1                                             Música
# 2                                       Bellas Artes
# 3                                                NaN
# 4                                           Sociales
#
#   Centro/Facultad II Centro/Facultad III Centro/Facultad IV  \
# 0                NaN                 NaN                NaN
# 1                NaN                 NaN                NaN
# 2         Psicología                 NaN                NaN
# 3                NaN                 NaN                NaN
# 4                NaN                 NaN                NaN
#
#   2a. Aclaración Otro  \
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
#   3. ¿Qué tipo de curso fue? (si fueron varios cursos, tome en cuenta el último curso que realizó)  \
# 0                                            Virtual
# 1  Semi presencial/Bi-modal (con instancias virtu...
# 2                                         Presencial
# 3                                                NaN
# 4                                            Virtual
#
#   4. ¿Cuánto horas/tiempo duró el curso?  \
# 0                         Entre 15-30 hs
# 1                         No lo recuerdo
# 2                         Entre 15-30 hs
# 3                                    NaN
# 4                         Entre 30-45 hs
#
#   5. ¿Que estrategias pedagógicas utilizó el docente para dictarlo? [Herramientas de video-conferencia (Zoom por ejemplo)]  \
# 0                                                 Si
# 1                                                 Si
# 2                                                 Si
# 3                                                NaN
# 4                                                 Si
#
#    ... 19. ¿Cuantos años tiene cumplidos a la fecha? (Edad en número)  \
# 0  ...                                               33.0
# 1  ...                                               24.0
# 2  ...                                               35.0
# 3  ...                                               45.0
# 4  ...                                               25.0
#
#   20. ¿En qué departamento vive? (en caso de alumno extranjero marcar "Otro país" y especificar el país)  \
# 0                                         Montevideo
# 1                                          Canelones
# 2                                         Montevideo
# 3                                         Montevideo
# 4                                         Montevideo
#
#   20a. Aclaración otro país 21. ¿En qué localidad o barrio reside?  \
# 0                       NaN                          Parque Batlle
# 1                       NaN                              Atlántida
# 2                       NaN                                Pocitos
# 3                       NaN                     Malvin/ Montevideo
# 4                       NaN                          La Blanqueada
#
#   22. ¿Cuántas horas a la semana trabaja? (Horas en números)  \
# 0                                                 40
# 1                                                  0
# 2                                                 25
# 3                                                 40
# 4                                                 49
#
#   23. ¿En qué tipo de institución trabaja? (si trabaja en más de un lugar, marque el que considere su principal fuente de ingreso)  \
# 0                                            Privada
# 1                    No estoy trabajando actualmente
# 2                                        Cooperativa
# 3                                            Privada
# 4                                          ONG / OSC
#
#   26. ¿Cuál es su máximo nivel de estudios alcanzado?  \
# 0                     12. Universidad grado completo
# 1                   11. Universidad grado incompleto
# 2                     12. Universidad grado completo
# 3                            17. Maestría incompleto
# 4                   11. Universidad grado incompleto
#
#   27. ¿En que año ingreso en la Universidad y/o centro de estudios terciarios? (año en números)  \
# 0                                               2018
# 1                                        2021 o 2022
# 2                                               2008
# 3                                               2014
# 4                                               2018
#
#   28. Y ¿En que año egreso? (año en números, si no egreso poner 0)  \
# 0                                               2022
# 1                                             Aún no
# 2                                               2015
# 3                                               2020
# 4                                                  0
#
#   29. Para cerrar, ¿Sus padres (madre y/o padre) tienen estudios universitarios y/o estudios terciarios en otra institución (IPA, Magisterio, UTU terciario, etc.)?
# 0  Si, tengo al menos un padre/madre universitari...
# 1  Si, tengo al menos un padre/madre universitari...
# 2  Si, tengo al menos un padre/madre universitari...
# 3  No, no tengo padres universitarios. Soy primer...
# 4  No, no tengo padres universitarios. Soy primer...
#
# [5 rows x 56 columns]

# %% [markdown]
# ## 1) Inspección inicial

# %%
print("Filas, Columnas:", df.shape)
#display(df.head(3))
#display(df.tail(3))
#list(df.columns)
# Out:
# Filas, Columnas: (739, 56)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 739 entries, 0 to 738
# Data columns (total 56 columns):
#  #   Column                                                                                                                                                                                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                 --------------  -----
#  0   Id                                                                                                                                                                                                                                                     739 non-null    int64
#  1   1. Para empezar ¿Cuántos cursos de educación permanente realizó el año pasado 2023?                                                                                                                                                                    739 non-null    object
#  2   2. ¿Desde qué centro/facultad realizó el/los cursos? (puede marcar todas las que correspondan en caso de haber realizado dos cursos o más en diferentes centros)                                                                                       697 non-null    object
#  3   Centro/Facultad II                                                                                                                                                                                                                                     70 non-null     object
#  4   Centro/Facultad III                                                                                                                                                                                                                                    12 non-null     object
#  5   Centro/Facultad IV                                                                                                                                                                                                                                     1 non-null      object
#  6   2a. Aclaración Otro                                                                                                                                                                                                                                    23 non-null     object
#  7   3. ¿Qué tipo de curso fue? (si fueron varios cursos, tome en cuenta el último curso que realizó)                                                                                                                                                       697 non-null    object
#  8   4. ¿Cuánto horas/tiempo duró el curso?                                                                                                                                                                                                                 697 non-null    object
#  9   5. ¿Que estrategias pedagógicas utilizó el docente para dictarlo? [Herramientas de video-conferencia (Zoom por ejemplo)]                                                                                                                               697 non-null    object
#  10  5. ¿Que estrategias pedagógicas utilizó el docente para dictarlo? [Presentaciones (ppt, pdf, etc.)]                                                                                                                                                    697 non-null    object
#  11  5. ¿Que estrategias pedagógicas utilizó el docente para dictarlo? [Herramientas interactivas (encuestas en vivo, foros, etc.)]                                                                                                                         697 non-null    object
#  12  5. ¿Que estrategias pedagógicas utilizó el docente para dictarlo? [Trabajo colaborativo]                                                                                                                                                               697 non-null    object
#  13  5. ¿Que estrategias pedagógicas utilizó el docente para dictarlo? [Formularios de auto-evaluación]                                                                                                                                                     697 non-null    object
#  14  5. ¿Que estrategias pedagógicas utilizó el docente para dictarlo? [Evaluación entre pares (corrección de trabajos entre los participantes)]                                                                                                            697 non-null    object
#  15  5. ¿Que estrategias pedagógicas utilizó el docente para dictarlo? [Evaluación automática (por ejemplo, prueba/parcial por formulario en EVA)]                                                                                                          697 non-null    object
#  16  5. ¿Que estrategias pedagógicas utilizó el docente para dictarlo? [Rúbrica docente (Tabla que indica los criterios que se evalúan y los niveles de calidad alcanzados)]                                                                                697 non-null    object
#  17  6. Más allá de los items anteriores, en el curso existieron actividades interactivas/participativas del siguiente tipo: [Talleres]                                                                                                                     697 non-null    object
#  18  6. Más allá de los items anteriores, en el curso existieron actividades interactivas/participativas del siguiente tipo: [Estudios de casos ]                                                                                                           697 non-null    object
#  19  6. Más allá de los items anteriores, en el curso existieron actividades interactivas/participativas del siguiente tipo: [Mesa redonda (por ejemplo charlas con invitados)]                                                                             697 non-null    object
#  20  6. Más allá de los items anteriores, en el curso existieron actividades interactivas/participativas del siguiente tipo: [Ateneos]                                                                                                                      697 non-null    object
#  21  6. Más allá de los items anteriores, en el curso existieron actividades interactivas/participativas del siguiente tipo: [Otra]                                                                                                                         697 non-null    object
#  22  7. Si tuviera que definir el curso en términos generales, diría que...                                                                                                                                                                                 697 non-null    object
#  23  8. ¿El último curso que realizó formaba parte de algún posgrado (diploma/maestría/doctorado)?                                                                                                                                                          697 non-null    object
#  24  9. ¿Recibe información de Educación Permanente sobre actividades y/o cursos?                                                                                                                                                                           697 non-null    object
#  25  10. ¿Por cuál medio se enteró de la existencia del último curso(s) que realizó? (Marqué hasta dos opciones)                                                                                                                                            697 non-null    object
#  26  Medio II                                                                                                                                                                                                                                               168 non-null    object
#  27  Medio III                                                                                                                                                                                                                                              39 non-null     object
#  28  Medio IV                                                                                                                                                                                                                                               8 non-null      object
#  29  11. ¿Con que frecuencia se entera de las novedades de la Udelar y de Educación Permanente?                                                                                                                                                             697 non-null    object
#  30  12. Sobre el último curso, en términos generales, en una escala de uno a diez, donde 1 es muy malo y diez excelente ¿Cómo evaluaría el curso?                                                                                                          697 non-null    float64
#  31  13. ¿Considera que los contenidos del curso fueron útiles para Ud.?                                                                                                                                                                                    697 non-null    object
#  32  14. El curso ¿Contribuyó positivamente en su trayectoria laboral?                                                                                                                                                                                      697 non-null    object
#  33  15. Le vamos a enunciar una serie de afirmaciones. Le pedimos que conteste su grado de acuerdo o desacuerdo... [15a Los cursos de Educación Permanente guardan mucha relación con las demandas del mundo laboral]                                      697 non-null    object
#  34  15. Le vamos a enunciar una serie de afirmaciones. Le pedimos que conteste su grado de acuerdo o desacuerdo... [15b. Los cursos de Educación Permanente son útiles para su profesión]                                                                  697 non-null    object
#  35  15. Le vamos a enunciar una serie de afirmaciones. Le pedimos que conteste su grado de acuerdo o desacuerdo... [15c. Los docentes se preocupan por ofrecer contenidos y formación acorde a las exigencias del mercado laboral cuando proponen cursos]  697 non-null    object
#  36  15. Le vamos a enunciar una serie de afirmaciones. Le pedimos que conteste su grado de acuerdo o desacuerdo... [15d. La Udelar se víncula con el mundo laboral a través de los cursos de Educación Permanente]                                         697 non-null    object
#  37  15. Le vamos a enunciar una serie de afirmaciones. Le pedimos que conteste su grado de acuerdo o desacuerdo... [15e. Los cursos atienden necesidades prácticas]                                                                                        697 non-null    object
#  38  16. Si tuviera que elegir entre un curso virtual o presencial...                                                                                                                                                                                       697 non-null    object
#  39  17. Por último, ¿Conoce y/o a realizado algún curso en alguna de estas plataformas? [Coursera]                                                                                                                                                         697 non-null    object
#  40  17. Por último, ¿Conoce y/o a realizado algún curso en alguna de estas plataformas? [Domestika]                                                                                                                                                        697 non-null    object
#  41  17. Por último, ¿Conoce y/o a realizado algún curso en alguna de estas plataformas? [Udemy]                                                                                                                                                            697 non-null    object
#  42  17. Por último, ¿Conoce y/o a realizado algún curso en alguna de estas plataformas? [Edx]                                                                                                                                                              697 non-null    object
#  43  17. Por último, ¿Conoce y/o a realizado algún curso en alguna de estas plataformas? [Otra]                                                                                                                                                             697 non-null    object
#  44  17a. Aclaración "Otra"                                                                                                                                                                                                                                 95 non-null     object
#  45  18. Le vamos a realizar algunas preguntas sobre Ud. para poder ordenar a los entrevistados.... ¿Cual es su Sexo/Género?                                                                                                                                737 non-null    object
#  46  19. ¿Cuantos años tiene cumplidos a la fecha? (Edad en número)                                                                                                                                                                                         738 non-null    float64
#  47  20. ¿En qué departamento vive? (en caso de alumno extranjero marcar "Otro país" y especificar el país)                                                                                                                                                 738 non-null    object
#  48  20a. Aclaración otro país                                                                                                                                                                                                                              17 non-null     object
#  49  21. ¿En qué localidad o barrio reside?                                                                                                                                                                                                                 711 non-null    object
#  50  22. ¿Cuántas horas a la semana trabaja? (Horas en números)                                                                                                                                                                                             737 non-null    object
#  51  23. ¿En qué tipo de institución trabaja? (si trabaja en más de un lugar, marque el que considere su principal fuente de ingreso)                                                                                                                       738 non-null    object
#  52  26. ¿Cuál es su máximo nivel de estudios alcanzado?                                                                                                                                                                                                    736 non-null    object
#  53  27. ¿En que año ingreso en la Universidad y/o centro de estudios terciarios? (año en números)                                                                                                                                                          688 non-null    object
#  54  28. Y ¿En que año egreso? (año en números, si no egreso poner 0)                                                                                                                                                                                       691 non-null    object
#  55  29. Para cerrar, ¿Sus padres (madre y/o padre) tienen estudios universitarios y/o estudios terciarios en otra institución (IPA, Magisterio, UTU terciario, etc.)?                                                                                      736 non-null    object
# dtypes: float64(2), int64(1), object(53)
# memory usage: 323.4+ KB

# %%
#Cuáles son las columnas con más datos faltantes y en qué proporción
na_pct = df.isna().mean().sort_values(ascending=False)
na_pct.head(10)
# Out:
# Centro/Facultad IV                                                                               0.998647
# Medio IV                                                                                         0.989175
# Centro/Facultad III                                                                              0.983762
# 20a. Aclaración otro país                                                                        0.976996
# 2a. Aclaración Otro                                                                              0.968877
# Medio III                                                                                        0.947226
# Centro/Facultad II                                                                               0.905277
# 17a. Aclaración "Otra"                                                                           0.871448
# Medio II                                                                                         0.772666
# 27. ¿En que año ingreso en la Universidad y/o centro de estudios terciarios? (año en números)    0.069012
# dtype: float64

# %% [markdown]
# ## 2) Limpieza básica

# %%
empty_cols = [c for c in df.columns if df[c].isna().all()]
print("Columnas completamente vacias:", len(empty_cols))
#df = df.drop(columns=empty_cols)
#df.shape
# Out:
# Columnas completamente vacias: 0

# %% [markdown]
# ## 3) Transformaciones útiles

# %%
# Binarias Si/No en varios bloques
bin_like = [c for c in df.columns if c.startswith(('5.','6.'))]
for c in bin_like:
    df[c] = df[c].map({"Si": 1, "No": 0}).astype('float')
print("Columnas binarias mapeadas:", len(bin_like))
df[bin_like].head(3)
# Out:
# Columnas binarias mapeadas: 13
#    5. ¿Que estrategias pedagógicas utilizó el docente para dictarlo? [Herramientas de video-conferencia (Zoom por ejemplo)]  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
#
#    5. ¿Que estrategias pedagógicas utilizó el docente para dictarlo? [Presentaciones (ppt, pdf, etc.)]  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
#
#    5. ¿Que estrategias pedagógicas utilizó el docente para dictarlo? [Herramientas interactivas (encuestas en vivo, foros, etc.)]  \
# 0                                                1.0
# 1                                                0.0
# 2                                                0.0
#
#    5. ¿Que estrategias pedagógicas utilizó el docente para dictarlo? [Trabajo colaborativo]  \
# 0                                                0.0
# 1                                                0.0
# 2                                                1.0
#
#    5. ¿Que estrategias pedagógicas utilizó el docente para dictarlo? [Formularios de auto-evaluación]  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    5. ¿Que estrategias pedagógicas utilizó el docente para dictarlo? [Evaluación entre pares (corrección de trabajos entre los participantes)]  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    5. ¿Que estrategias pedagógicas utilizó el docente para dictarlo? [Evaluación automática (por ejemplo, prueba/parcial por formulario en EVA)]  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    5. ¿Que estrategias pedagógicas utilizó el docente para dictarlo? [Rúbrica docente (Tabla que indica los criterios que se evalúan y los niveles de calidad alcanzados)]  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    6. Más allá de los items anteriores, en el curso existieron actividades interactivas/participativas del siguiente tipo: [Talleres]  \
# 0                                                0.0
# 1                                                1.0
# 2                                                1.0
#
#    6. Más allá de los items anteriores, en el curso existieron actividades interactivas/participativas del siguiente tipo: [Estudios de casos ]  \
# 0                                                1.0
# 1                                                1.0
# 2                                                0.0
#
#    6. Más allá de los items anteriores, en el curso existieron actividades interactivas/participativas del siguiente tipo: [Mesa redonda (por ejemplo charlas con invitados)]  \
# 0                                                1.0
# 1                                                0.0
# 2                                                0.0
#
#    6. Más allá de los items anteriores, en el curso existieron actividades interactivas/participativas del siguiente tipo: [Ateneos]  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    6. Más allá de los items anteriores, en el curso existieron actividades interactivas/participativas del siguiente tipo: [Otra]
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0

# %%
# Quiero saber cuántas personas completaron la encuesta
#1) Identifico la columna de la pregunta 1
col_p1 = [c for c in df.columns if c.startswith('1.')][0]

# 2) Defino el texto objetivo
target = "Ninguno (Terminar encuesta y pasar a la pregunta 18)"

# 3) Creo la máscara de coincidencia robusta (ignora mayúsculas y espacios extra)
mask = (
    df[col_p1]
      .astype(str)                # por si hay NaN
      .str.strip()                # quita espacios iniciales/finales
      .str.casefold()             # compara sin sensibilidad a mayúsculas/minúsculas
      .eq(target.strip().casefold())
)

# 4) Conteo y porcentaje
cantidad = mask.sum()
porcentaje = (cantidad / len(df)) * 100 if len(df) else 0

print("Columna P1:", col_p1)
print("Cantidad que marcaron 'Ninguno (Terminar encuesta y pasar a la pregunta 18)':", cantidad)
print(f"Porcentaje sobre el total: {porcentaje:.1f}%")
# Out:
# Columna P1: 1. Para empezar ¿Cuántos cursos de educación permanente realizó el año pasado 2023?
# Cantidad que marcaron 'Ninguno (Terminar encuesta y pasar a la pregunta 18)': 42
# Porcentaje sobre el total: 5.7%

# %%
df[col_p1].value_counts(dropna=False)
# Out:
# 1. Para empezar ¿Cuántos cursos de educación permanente realizó el año pasado 2023?
# Un curso                                                393
# Dos cursos                                              168
# Cuatro cursos o más                                      65
# Tres cursos                                              65
# Ninguno (Terminar encuesta y pasar a la pregunta 18)     42
# 99                                                        6
# Name: count, dtype: int64

# %% [markdown]
# ## 4) Análisis Estadístico

# %%
## Cálculos Estadísticos Descriptivos
#Usamos comandos de Pandas simples para obtener resúmenes rápidos de los datos.

# Cálculos Estadísticos Descriptivos

print("--- Resumen Estadístico de la Edad ---")
# describe() es una de las funciones más potentes para ver la distribución central
print(df['19. ¿Cuantos años tiene cumplidos a la fecha? (Edad en número)'].describe())
# Out:
# --- Resumen Estadístico de la Edad ---
# count    738.000000
# mean      39.345528
# std       11.611467
# min       18.000000
# 25%       30.000000
# 50%       38.000000
# 75%       48.000000
# max       99.000000
# Name: 19. ¿Cuantos años tiene cumplidos a la fecha? (Edad en número), dtype: float64

# %%
print("\n--- Conteo por Tipo de Curso (Variable Categórica) ---")
# value_counts() muestra la frecuencia de cada categoría
print(df['3. ¿Qué tipo de curso fue? (si fueron varios cursos, tome en cuenta el último curso que realizó)'].value_counts(dropna=False))

# %% [markdown]
# ## 5) Análisis Estadístico y Correlación

# %% [markdown]
# Vamos a analizar si existe correlación entre la duración del curso y las horas que trabaja por semana

# %%
df['4. ¿Cuánto horas/tiempo duró el curso?'].value_counts(dropna=False)
# Out:
# 4. ¿Cuánto horas/tiempo duró el curso?
# Entre 15-30 hs    228
# No lo recuerdo    156
# Entre 30-45 hs    111
# 15 hs o menos     110
# Más de 45 hs       85
# NaN                42
# 99                  7
# Name: count, dtype: int64

# %%
df['22. ¿Cuántas horas a la semana trabaja? (Horas en números)'].value_counts(dropna=False)
# Out:
# 22. ¿Cuántas horas a la semana trabaja? (Horas en números)
# 40        168
# 30         97
# 0          56
# 48         36
# 50         32
#          ...
# 5           1
# 39          1
# 18          1
# 27          1
# Muchas      1
# Name: count, Length: 62, dtype: int64

# %%
#LIMPIEZA, RENOMBRAMIENTO Y CONVERSIÓN A NUMÉRICA (FINAL)

# 1. Renombrar columnas clave:
df = df.rename(columns={
    '4. ¿Cuánto horas/tiempo duró el curso?': 'Duracion_Curso_cat',
    '22. ¿Cuántas horas a la semana trabaja? (Horas en números)': 'Horas_Trabajadas_Semana_num',
    # Añade más si las estás usando en el Notebook:
    '9. ¿Cuál es su edad?': 'Edad',
})

# 2. Mapeo para Duración del Curso (Numérica)
mapeo_duracion = {
    '15 hs o menos': 7.5,
    'Entre 15-30 hs': 22.5,
    'Entre 30-45 hs': 37.5,
    'Más de 45 hs': 60,
    'No lo recuerdo': np.nan     # Convertimos explícitamente a NaN
}
df['Duracion_Curso_Numerica'] = df['Duracion_Curso_cat'].map(mapeo_duracion)

# 3. Asegurar tipo de dato para el cálculo
df['Duracion_Curso_Numerica'] = df['Duracion_Curso_Numerica'].astype(float)
# Usamos .astype(float) para asegurar que la columna de horas esté lista para cálculos
df['Horas_Trabajadas_Semana_num'] = df['Horas_Trabajadas_Semana_num'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2713570588.py in <cell line: 0>()
#      22 df['Duracion_Curso_Numerica'] = df['Duracion_Curso_Numerica'].astype(float)
#      23 # Usamos .astype(float) para asegurar que la columna de horas esté lista para cálculos
# ---> 24 df['Horas_Trabajadas_Semana_num'] = df['Horas_Trabajadas_Semana_num'].astype(float)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     361                 applied = b.apply(f, **kwargs)
#     362             else:
# --> 363                 applied = getattr(b, f)(**kwargs)
#     364             result_blocks = extend_blocks(applied, result_blocks)
#     365
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, using_cow, squeeze)
#     756             values = values[0, :]  # type: ignore[call-overload]
#     757
# --> 758         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     759
#     760         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     235
#     236     try:
# --> 237         new_values = astype_array(values, dtype, copy=copy)
#     238     except (ValueError, TypeError):
#     239         # e.g. _astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     180
#     181     else:
# --> 182         values = _astype_nansafe(values, dtype, copy=copy)
#     183
#     184     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/dtypes/astype.py in _astype_nansafe(arr, dtype, copy, skipna)
#     131     if copy or arr.dtype == object or dtype == object:
#     132         # Explicit copy, or required since NumPy can't view from / to object.
# --> 133         return arr.astype(dtype, copy=True)
#     134
#     135     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '8-9 h'

# %%
# 1. Definir los mapeos: ¿Qué valor de texto se convierte en qué número?
mapeo_horas = {
    '8-9 h': 8.0,
    'Muchas': 40.0,

}

# 2. Aplicar la sustitución de valores
# Se utiliza el parámetro 'regex=False' para asegurar que el mapeo sea exacto.
df['Horas_Trabajadas_Semana_num'] = (
    df['Horas_Trabajadas_Semana_num']
    .replace(mapeo_horas)
)

# 3. Conversión final a float
# Si la columna contiene ahora solo números y NaNs, este paso debería funcionar.
try:
    df['Horas_Trabajadas_Semana_num'] = df['Horas_Trabajadas_Semana_num'].astype(float)
    print("✅ La columna ha sido actualizada y convertida a tipo float.")
except ValueError as e:
    print(f"🛑 Error de conversión: {e}")
    print("Aún quedan valores de texto no mapeados o caracteres extra (ej. ' h', ' -') que impiden la conversión. Debes mapearlos o eliminarlos.")
# Out:
# ✅ La columna ha sido actualizada y convertida a tipo float.

# %%
df['Duracion_Curso_Numerica'] = df['Duracion_Curso_cat'].map(mapeo_duracion)

# 3. Asegurar tipo de dato para el cálculo
df['Duracion_Curso_Numerica'] = df['Duracion_Curso_Numerica'].astype(float)
# Usamos .astype(float) para asegurar que la columna de horas esté lista para cálculos
df['Horas_Trabajadas_Semana_num'] = df['Horas_Trabajadas_Semana_num'].astype(float)

# %%
# CÁLCULO DE CORRELACIÓN CON IMPUTACIÓN DE LA MEDIA

# 1. Definir las columnas a usar
duracion = df['Duracion_Curso_Numerica']
horas_trabajadas = df['Horas_Trabajadas_Semana_num']

# 2. GESTIÓN CRÍTICA DE NaN (IMPUTACIÓN POR LA MEDIA)
# Rellenamos los NaN con el promedio de cada columna para permitir el cálculo.
duracion_limpia = duracion.fillna(duracion.mean())
horas_trabajadas_limpia = horas_trabajadas.fillna(horas_trabajadas.mean())

# 3. Calculamos la correlación.
correlacion = duracion_limpia.corr(horas_trabajadas_limpia)

print("--- Coeficiente de Correlación de Pearson ---")
print(f"Correlación (Duración del Curso vs. Horas Trabajadas Semanales): {correlacion:.3f}")

# 4. Interpretación del resultado
if abs(correlacion) < 0.2:
    fuerza = "débil o nula"
    accion = "No hay una relación lineal significativa."
elif abs(correlacion) < 0.5:
    fuerza = "moderada"
    accion = "Existe una leve tendencia."
else:
    fuerza = "fuerte"
    accion = "Hay una clara relación lineal."

tendencia = "inversa" if correlacion < 0 else "directa"

print(f"Resultado: La correlación es {fuerza} y de tendencia {tendencia}. {accion}")
# Out:
# --- Coeficiente de Correlación de Pearson ---
# Correlación (Duración del Curso vs. Horas Trabajadas Semanales): 0.009
# Resultado: La correlación es débil o nula y de tendencia directa. No hay una relación lineal significativa.
